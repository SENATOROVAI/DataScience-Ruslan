# %%
"""Логирование уроков."""

# %% [markdown]
# 21/09
#
# 1) выяснено мой стек технологий,
# 2) объяснено подход ментора к подаче материала при обучении (в общем),
# 3) выяснено профиль Дата Аналитика (по вакансиям),
# 4) выдана программа изучения материалов, чтобы стать Дата Аналитиком,
# 5) показано какие материалы (книги) по математике нужно учить в первую очередь.
